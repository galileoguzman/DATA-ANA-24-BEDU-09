# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

df = pd.read_csv('tmp/Proyectos.csv')

df.head()
# Out:
#                                  Nombre del Proyecto  \
# 0  ESCALAMIENTO INDUSTRIAL DE UN MODELO BIOSEGURO...
# 1  CREA-CIENCIAS                                 ...
# 2  TERCER ENCUENTRO ESTATAL DE JOVENES INVESTIGAD...
# 3  DESARROLLO Y TRANSFERENCIA DE BIOTECNOLOGIAS P...
# 4  FORTALECIMIENTO DEL LABORATORIO AVANZADO DE EC...
#
#      Nombre del Titular del Proyecto  Tipo de Recurso  \
# 0  MAGALLON BARAJAS FRANCISCO JAVIER  RECURSO CONACYT
# 1           DIAZ CASTRO SARA CECILIA  RECURSO CONACYT
# 2           DIAZ CASTRO SARA CECILIA  RECURSO CONACYT
# 3       SALINAS ZAVALA CESAR AUGUSTO  RECURSO CONACYT
# 4          MORALES BOJORQUEZ ENRIQUE  RECURSO CONACYT
#
#                                         Convocatoria  \
# 0  FINNOVA                                       ...
# 1  Programa de fomento a la vocaciones CONACYT   ...
# 2  Programa de fomento a la vocaciones CONACYT   ...
# 3  Catedras                                      ...
# 4  Infraestructura CONACyT                       ...
#
#                         Rubro Fecha de Inicio Fecha de Finalizacion  \
# 0           EMPRESAS APOYADAS      24/02/2015            24/02/2017
# 1        DESARROLLO SECTORIAL      01/01/2015            31/12/2015
# 2        DESARROLLO SECTORIAL      01/01/2015            31/12/2015
# 3  GENERACION DE CONOCIMIENTO      20/04/2015            29/01/2016
# 4  GENERACION DE CONOCIMIENTO      11/06/2015            31/12/2015
#
#                          Instituciones participantes  \
# 0                                                NaN
# 1                                                NaN
# 2  UABCS, Tecnologico de La Paz, Universidad Mund...
# 3                                   CONACyT-CATEDRAS
# 4  Al ser proyecto de infraestructura solo partic...
#
#                                             Objetivo  \
# 0                                                NaN
# 1  Estimular la vocacion de jovenes estudiantes d...
# 2  Estimular a los jovenes a titularse mediante t...
# 3  Desarrollar, validar y escalar procesos biotec...
# 4  Establecer un laboratorio de analisis cuantita...
#
#                                           Programa  Ejercicio  Unnamed: 11  \
# 0                          PROGRAMA DE ACUICULTURA       2015          NaN
# 1  PROGRAMA DE PLANEACION AMBIENTAL Y CONSERVACION       2015          NaN
# 2  PROGRAMA DE PLANEACION AMBIENTAL Y CONSERVACION       2015          NaN
# 3                    PROGRAMA DE ECOLOGIA PESQUERA       2015          NaN
# 4                    PROGRAMA DE ECOLOGIA PESQUERA       2015          NaN
#
#    Unnamed: 12
# 0          NaN
# 1          NaN
# 2          NaN
# 3          NaN
# 4          NaN

# %% [markdown]
# ### Distribucion de proyectos por anio

# %%
plt.figure(figsize=(10,6))
sns.countplot(x='Ejercicio', data=df, palette='coolwarm')
plt.title('Distribucion de proyectos por anio')
plt.xlabel('Anio')
plt.ylabel('Cantidad de proyectos')

plt.show()
# Out:
# /var/folders/6_/r04zmw_d7zv8wp6sllj4wr5c0000gn/T/ipykernel_8688/536990055.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x='Ejercicio', data=df, palette='coolwarm')

# %% [markdown]
# ## Duracion promedio de los proyectos por rubro

# %%
df.head()
# Out:
#                                  Nombre del Proyecto  \
# 0  ESCALAMIENTO INDUSTRIAL DE UN MODELO BIOSEGURO...
# 1  CREA-CIENCIAS                                 ...
# 2  TERCER ENCUENTRO ESTATAL DE JOVENES INVESTIGAD...
# 3  DESARROLLO Y TRANSFERENCIA DE BIOTECNOLOGIAS P...
# 4  FORTALECIMIENTO DEL LABORATORIO AVANZADO DE EC...
#
#      Nombre del Titular del Proyecto  Tipo de Recurso  \
# 0  MAGALLON BARAJAS FRANCISCO JAVIER  RECURSO CONACYT
# 1           DIAZ CASTRO SARA CECILIA  RECURSO CONACYT
# 2           DIAZ CASTRO SARA CECILIA  RECURSO CONACYT
# 3       SALINAS ZAVALA CESAR AUGUSTO  RECURSO CONACYT
# 4          MORALES BOJORQUEZ ENRIQUE  RECURSO CONACYT
#
#                                         Convocatoria  \
# 0  FINNOVA                                       ...
# 1  Programa de fomento a la vocaciones CONACYT   ...
# 2  Programa de fomento a la vocaciones CONACYT   ...
# 3  Catedras                                      ...
# 4  Infraestructura CONACyT                       ...
#
#                         Rubro Fecha de Inicio Fecha de Finalizacion  \
# 0           EMPRESAS APOYADAS      24/02/2015            24/02/2017
# 1        DESARROLLO SECTORIAL      01/01/2015            31/12/2015
# 2        DESARROLLO SECTORIAL      01/01/2015            31/12/2015
# 3  GENERACION DE CONOCIMIENTO      20/04/2015            29/01/2016
# 4  GENERACION DE CONOCIMIENTO      11/06/2015            31/12/2015
#
#                          Instituciones participantes  \
# 0                                                NaN
# 1                                                NaN
# 2  UABCS, Tecnologico de La Paz, Universidad Mund...
# 3                                   CONACyT-CATEDRAS
# 4  Al ser proyecto de infraestructura solo partic...
#
#                                             Objetivo  \
# 0                                                NaN
# 1  Estimular la vocacion de jovenes estudiantes d...
# 2  Estimular a los jovenes a titularse mediante t...
# 3  Desarrollar, validar y escalar procesos biotec...
# 4  Establecer un laboratorio de analisis cuantita...
#
#                                           Programa  Ejercicio  Unnamed: 11  \
# 0                          PROGRAMA DE ACUICULTURA       2015          NaN
# 1  PROGRAMA DE PLANEACION AMBIENTAL Y CONSERVACION       2015          NaN
# 2  PROGRAMA DE PLANEACION AMBIENTAL Y CONSERVACION       2015          NaN
# 3                    PROGRAMA DE ECOLOGIA PESQUERA       2015          NaN
# 4                    PROGRAMA DE ECOLOGIA PESQUERA       2015          NaN
#
#    Unnamed: 12
# 0          NaN
# 1          NaN
# 2          NaN
# 3          NaN
# 4          NaN

# %%
df['Fecha de Inicio'] = pd.to_datetime(df['Fecha de Inicio'])
df['Fecha de Finalizacion'] = pd.to_datetime(df['Fecha de Finalizacion'])

df['Duracion (Dias)'] = (df['Fecha de Finalizacion'] - df['Fecha de Inicio']).dt.days

df.head()
# Out:
#                                  Nombre del Proyecto  \
# 0  ESCALAMIENTO INDUSTRIAL DE UN MODELO BIOSEGURO...
# 1  CREA-CIENCIAS                                 ...
# 2  TERCER ENCUENTRO ESTATAL DE JOVENES INVESTIGAD...
# 3  DESARROLLO Y TRANSFERENCIA DE BIOTECNOLOGIAS P...
# 4  FORTALECIMIENTO DEL LABORATORIO AVANZADO DE EC...
#
#      Nombre del Titular del Proyecto  Tipo de Recurso  \
# 0  MAGALLON BARAJAS FRANCISCO JAVIER  RECURSO CONACYT
# 1           DIAZ CASTRO SARA CECILIA  RECURSO CONACYT
# 2           DIAZ CASTRO SARA CECILIA  RECURSO CONACYT
# 3       SALINAS ZAVALA CESAR AUGUSTO  RECURSO CONACYT
# 4          MORALES BOJORQUEZ ENRIQUE  RECURSO CONACYT
#
#                                         Convocatoria  \
# 0  FINNOVA                                       ...
# 1  Programa de fomento a la vocaciones CONACYT   ...
# 2  Programa de fomento a la vocaciones CONACYT   ...
# 3  Catedras                                      ...
# 4  Infraestructura CONACyT                       ...
#
#                         Rubro Fecha de Inicio Fecha de Finalizacion  \
# 0           EMPRESAS APOYADAS      2015-02-24            2017-02-24
# 1        DESARROLLO SECTORIAL      2015-01-01            2015-12-31
# 2        DESARROLLO SECTORIAL      2015-01-01            2015-12-31
# 3  GENERACION DE CONOCIMIENTO      2015-04-20            2016-01-29
# 4  GENERACION DE CONOCIMIENTO      2015-06-11            2015-12-31
#
#                          Instituciones participantes  \
# 0                                                NaN
# 1                                                NaN
# 2  UABCS, Tecnologico de La Paz, Universidad Mund...
# 3                                   CONACyT-CATEDRAS
# 4  Al ser proyecto de infraestructura solo partic...
#
#                                             Objetivo  \
# 0                                                NaN
# 1  Estimular la vocacion de jovenes estudiantes d...
# 2  Estimular a los jovenes a titularse mediante t...
# 3  Desarrollar, validar y escalar procesos biotec...
# 4  Establecer un laboratorio de analisis cuantita...
#
#                                           Programa  Ejercicio  Unnamed: 11  \
# 0                          PROGRAMA DE ACUICULTURA       2015          NaN
# 1  PROGRAMA DE PLANEACION AMBIENTAL Y CONSERVACION       2015          NaN
# 2  PROGRAMA DE PLANEACION AMBIENTAL Y CONSERVACION       2015          NaN
# 3                    PROGRAMA DE ECOLOGIA PESQUERA       2015          NaN
# 4                    PROGRAMA DE ECOLOGIA PESQUERA       2015          NaN
#
#    Unnamed: 12  Duracion (Dias)
# 0          NaN              731
# 1          NaN              364
# 2          NaN              364
# 3          NaN              284
# 4          NaN              203

# %%
plt.figure(figsize=(10,6))
sns.barplot(x='Rubro', y='Duracion (Dias)', data=df, estimator=lambda x: x.mean(), palette='magma')
plt.title('Duracion promedio de proyectos')
plt.xlabel('Rubro')
plt.ylabel('Duracion en dias')
plt.xticks(rotation=45)

plt.show()
# Out:
# /var/folders/6_/r04zmw_d7zv8wp6sllj4wr5c0000gn/T/ipykernel_8688/3001435190.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='Rubro', y='Duracion (Dias)', data=df, estimator=lambda x: x.mean(), palette='magma')

# %% [markdown]
# ### Mapa de calor por tipo de recurso y rubro

# %%
df.head()
# Out:
#                                  Nombre del Proyecto  \
# 0  ESCALAMIENTO INDUSTRIAL DE UN MODELO BIOSEGURO...
# 1  CREA-CIENCIAS                                 ...
# 2  TERCER ENCUENTRO ESTATAL DE JOVENES INVESTIGAD...
# 3  DESARROLLO Y TRANSFERENCIA DE BIOTECNOLOGIAS P...
# 4  FORTALECIMIENTO DEL LABORATORIO AVANZADO DE EC...
#
#      Nombre del Titular del Proyecto  Tipo de Recurso  \
# 0  MAGALLON BARAJAS FRANCISCO JAVIER  RECURSO CONACYT
# 1           DIAZ CASTRO SARA CECILIA  RECURSO CONACYT
# 2           DIAZ CASTRO SARA CECILIA  RECURSO CONACYT
# 3       SALINAS ZAVALA CESAR AUGUSTO  RECURSO CONACYT
# 4          MORALES BOJORQUEZ ENRIQUE  RECURSO CONACYT
#
#                                         Convocatoria  \
# 0  FINNOVA                                       ...
# 1  Programa de fomento a la vocaciones CONACYT   ...
# 2  Programa de fomento a la vocaciones CONACYT   ...
# 3  Catedras                                      ...
# 4  Infraestructura CONACyT                       ...
#
#                         Rubro Fecha de Inicio Fecha de Finalizacion  \
# 0           EMPRESAS APOYADAS      2015-02-24            2017-02-24
# 1        DESARROLLO SECTORIAL      2015-01-01            2015-12-31
# 2        DESARROLLO SECTORIAL      2015-01-01            2015-12-31
# 3  GENERACION DE CONOCIMIENTO      2015-04-20            2016-01-29
# 4  GENERACION DE CONOCIMIENTO      2015-06-11            2015-12-31
#
#                          Instituciones participantes  \
# 0                                                NaN
# 1                                                NaN
# 2  UABCS, Tecnologico de La Paz, Universidad Mund...
# 3                                   CONACyT-CATEDRAS
# 4  Al ser proyecto de infraestructura solo partic...
#
#                                             Objetivo  \
# 0                                                NaN
# 1  Estimular la vocacion de jovenes estudiantes d...
# 2  Estimular a los jovenes a titularse mediante t...
# 3  Desarrollar, validar y escalar procesos biotec...
# 4  Establecer un laboratorio de analisis cuantita...
#
#                                           Programa  Ejercicio  Unnamed: 11  \
# 0                          PROGRAMA DE ACUICULTURA       2015          NaN
# 1  PROGRAMA DE PLANEACION AMBIENTAL Y CONSERVACION       2015          NaN
# 2  PROGRAMA DE PLANEACION AMBIENTAL Y CONSERVACION       2015          NaN
# 3                    PROGRAMA DE ECOLOGIA PESQUERA       2015          NaN
# 4                    PROGRAMA DE ECOLOGIA PESQUERA       2015          NaN
#
#    Unnamed: 12  Duracion (Dias)
# 0          NaN              731
# 1          NaN              364
# 2          NaN              364
# 3          NaN              284
# 4          NaN              203

# %%
pivot_table = df.pivot_table(
    index='Tipo de Recurso',
    columns='Rubro',
    aggfunc='size',
    fill_value=0
)


plt.figure(figsize=(10,6))
sns.heatmap(pivot_table, annot=True, cmap='Blues')

plt.title('Proyectos por tipo de recurso y rubro')
plt.xlabel('Rubro')
plt.ylabel('Tipo de recurso')

plt.show()

# %% [markdown]
# ### Proyectos comunes por institucion

# %%
df.head()
# Out:
#                                  Nombre del Proyecto  \
# 0  ESCALAMIENTO INDUSTRIAL DE UN MODELO BIOSEGURO...
# 1  CREA-CIENCIAS                                 ...
# 2  TERCER ENCUENTRO ESTATAL DE JOVENES INVESTIGAD...
# 3  DESARROLLO Y TRANSFERENCIA DE BIOTECNOLOGIAS P...
# 4  FORTALECIMIENTO DEL LABORATORIO AVANZADO DE EC...
#
#      Nombre del Titular del Proyecto  Tipo de Recurso  \
# 0  MAGALLON BARAJAS FRANCISCO JAVIER  RECURSO CONACYT
# 1           DIAZ CASTRO SARA CECILIA  RECURSO CONACYT
# 2           DIAZ CASTRO SARA CECILIA  RECURSO CONACYT
# 3       SALINAS ZAVALA CESAR AUGUSTO  RECURSO CONACYT
# 4          MORALES BOJORQUEZ ENRIQUE  RECURSO CONACYT
#
#                                         Convocatoria  \
# 0  FINNOVA                                       ...
# 1  Programa de fomento a la vocaciones CONACYT   ...
# 2  Programa de fomento a la vocaciones CONACYT   ...
# 3  Catedras                                      ...
# 4  Infraestructura CONACyT                       ...
#
#                         Rubro Fecha de Inicio Fecha de Finalizacion  \
# 0           EMPRESAS APOYADAS      2015-02-24            2017-02-24
# 1        DESARROLLO SECTORIAL      2015-01-01            2015-12-31
# 2        DESARROLLO SECTORIAL      2015-01-01            2015-12-31
# 3  GENERACION DE CONOCIMIENTO      2015-04-20            2016-01-29
# 4  GENERACION DE CONOCIMIENTO      2015-06-11            2015-12-31
#
#                          Instituciones participantes  \
# 0                                                NaN
# 1                                                NaN
# 2  UABCS, Tecnologico de La Paz, Universidad Mund...
# 3                                   CONACyT-CATEDRAS
# 4  Al ser proyecto de infraestructura solo partic...
#
#                                             Objetivo  \
# 0                                                NaN
# 1  Estimular la vocacion de jovenes estudiantes d...
# 2  Estimular a los jovenes a titularse mediante t...
# 3  Desarrollar, validar y escalar procesos biotec...
# 4  Establecer un laboratorio de analisis cuantita...
#
#                                           Programa  Ejercicio  Unnamed: 11  \
# 0                          PROGRAMA DE ACUICULTURA       2015          NaN
# 1  PROGRAMA DE PLANEACION AMBIENTAL Y CONSERVACION       2015          NaN
# 2  PROGRAMA DE PLANEACION AMBIENTAL Y CONSERVACION       2015          NaN
# 3                    PROGRAMA DE ECOLOGIA PESQUERA       2015          NaN
# 4                    PROGRAMA DE ECOLOGIA PESQUERA       2015          NaN
#
#    Unnamed: 12  Duracion (Dias)
# 0          NaN              731
# 1          NaN              364
# 2          NaN              364
# 3          NaN              284
# 4          NaN              203

# %%
df['Instituciones'] = df['Instituciones participantes'].str.split(',')
df.head()
# Out:
#                                  Nombre del Proyecto  \
# 0  ESCALAMIENTO INDUSTRIAL DE UN MODELO BIOSEGURO...
# 1  CREA-CIENCIAS                                 ...
# 2  TERCER ENCUENTRO ESTATAL DE JOVENES INVESTIGAD...
# 3  DESARROLLO Y TRANSFERENCIA DE BIOTECNOLOGIAS P...
# 4  FORTALECIMIENTO DEL LABORATORIO AVANZADO DE EC...
#
#      Nombre del Titular del Proyecto  Tipo de Recurso  \
# 0  MAGALLON BARAJAS FRANCISCO JAVIER  RECURSO CONACYT
# 1           DIAZ CASTRO SARA CECILIA  RECURSO CONACYT
# 2           DIAZ CASTRO SARA CECILIA  RECURSO CONACYT
# 3       SALINAS ZAVALA CESAR AUGUSTO  RECURSO CONACYT
# 4          MORALES BOJORQUEZ ENRIQUE  RECURSO CONACYT
#
#                                         Convocatoria  \
# 0  FINNOVA                                       ...
# 1  Programa de fomento a la vocaciones CONACYT   ...
# 2  Programa de fomento a la vocaciones CONACYT   ...
# 3  Catedras                                      ...
# 4  Infraestructura CONACyT                       ...
#
#                         Rubro Fecha de Inicio Fecha de Finalizacion  \
# 0           EMPRESAS APOYADAS      2015-02-24            2017-02-24
# 1        DESARROLLO SECTORIAL      2015-01-01            2015-12-31
# 2        DESARROLLO SECTORIAL      2015-01-01            2015-12-31
# 3  GENERACION DE CONOCIMIENTO      2015-04-20            2016-01-29
# 4  GENERACION DE CONOCIMIENTO      2015-06-11            2015-12-31
#
#                          Instituciones participantes  \
# 0                                                NaN
# 1                                                NaN
# 2  UABCS, Tecnologico de La Paz, Universidad Mund...
# 3                                   CONACyT-CATEDRAS
# 4  Al ser proyecto de infraestructura solo partic...
#
#                                             Objetivo  \
# 0                                                NaN
# 1  Estimular la vocacion de jovenes estudiantes d...
# 2  Estimular a los jovenes a titularse mediante t...
# 3  Desarrollar, validar y escalar procesos biotec...
# 4  Establecer un laboratorio de analisis cuantita...
#
#                                           Programa  Ejercicio  Unnamed: 11  \
# 0                          PROGRAMA DE ACUICULTURA       2015          NaN
# 1  PROGRAMA DE PLANEACION AMBIENTAL Y CONSERVACION       2015          NaN
# 2  PROGRAMA DE PLANEACION AMBIENTAL Y CONSERVACION       2015          NaN
# 3                    PROGRAMA DE ECOLOGIA PESQUERA       2015          NaN
# 4                    PROGRAMA DE ECOLOGIA PESQUERA       2015          NaN
#
#    Unnamed: 12  Duracion (Dias)  \
# 0          NaN              731
# 1          NaN              364
# 2          NaN              364
# 3          NaN              284
# 4          NaN              203
#
#                                        Instituciones
# 0                                                NaN
# 1                                                NaN
# 2  [UABCS,  Tecnologico de La Paz,  Universidad M...
# 3                                 [CONACyT-CATEDRAS]
# 4  [Al ser proyecto de infraestructura solo parti...

# %%
instituciones = df.explode('Instituciones')['Instituciones'].value_counts()
instituciones
# Out:
# Instituciones
# COSCYT                                                                                              40
#  S.A. DE C.V.                                                                                       29
# KAMPACHI FARMS MEXICO                                                                               12
# IPICYT                                                                                               9
# ESSA                                                                                                 9
#                                                                                                     ..
#  GEOGRAFIA E INFORMATICAUNIVERSIDAD ESTATAL DE SONORAUNIVERSIDAD AUTONOMA DE BAJA CALIFORNIA SUR     1
# INSTITUTO NACIONAL DE ESTADISTICA                                                                    1
#  VitaGenesis y Nano Labs Technology                                                                  1
# Novaquatic solutions                                                                                 1
#  Universidad de Bretana Ocidental.                                                                   1
# Name: count, Length: 621, dtype: int64

# %%
plt.figure(figsize=(10,6))
sns.barplot(x=instituciones.values[:10], y=instituciones.index[:10], palette='Set2')

plt.title('Instituciones que mas participan')
plt.xlabel('Cantidad de participaciones')
plt.ylabel('Institucion')

plt.show()
# Out:
# /var/folders/6_/r04zmw_d7zv8wp6sllj4wr5c0000gn/T/ipykernel_8688/490392274.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=instituciones.values[:10], y=instituciones.index[:10], palette='Set2')

# %% [markdown]
# ### Prouyectos por convocatoria

# %%
plt.figure(figsize=(10,6))
df['Convocatoria'].value_counts()[:10].plot(kind='pie', autopct='%1.1f%%', startangle=90, cmap='coolwarm')

plt.title('Proyectos por convocatoria')
plt.ylabel('')
plt.show()
